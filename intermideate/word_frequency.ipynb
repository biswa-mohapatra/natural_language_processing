# %% [markdown]
# # Word Frequency in Data
# Counting the unique words in our data gives an idea about our data’s most frequent, least frequent terms. Often we drop the least frequent comments to make our model training more generalized.

# %%
paragraph = """Tokenization means splitting text into meaningful unit words. There are sentence tokenizers as well as word tokenizers.

Sentence tokenizer splits a paragraph into meaningful sentences, while word tokenizer splits a sentence into unit meaningful words. Many libraries can perform tokenization like SpaCy, NLTK, and TextBlob.

Splitting a sentence on space to get individual unit words can be understood as tokenization."""

# %%
# custom method:
freq = {}
for word in paragraph.split(" "):
    if not word in list(freq.keys()):
        freq[word] = 1
    else:
        freq[word]+=1

# %%
freq
# Out:
# {'Tokenization': 1,
#  'means': 1,
#  'splitting': 1,
#  'text': 1,
#  'into': 3,
#  'meaningful': 3,
#  'unit': 3,
#  'words.': 2,
#  'There': 1,
#  'are': 1,
#  'sentence': 3,
#  'tokenizers': 1,
#  'as': 3,
#  'well': 1,
#  'word': 2,
#  'tokenizers.\n\nSentence': 1,
#  'tokenizer': 2,
#  'splits': 2,
#  'a': 3,
#  'paragraph': 1,
#  'sentences,': 1,
#  'while': 1,
#  'Many': 1,
#  'libraries': 1,
#  'can': 2,
#  'perform': 1,
#  'tokenization': 1,
#  'like': 1,
#  'SpaCy,': 1,
#  'NLTK,': 1,
#  'and': 1,
#  'TextBlob.\n\nSplitting': 1,
#  'on': 1,
#  'space': 1,
#  'to': 1,
#  'get': 1,
#  'individual': 1,
#  'words': 1,
#  'be': 1,
#  'understood': 1,
#  'tokenization.': 1}

# %%
# library
all_words = [w for w in paragraph.split(" ")]

# %%
import nltk
nltk.FreqDist(all_words)
# Out:
# FreqDist({'into': 3, 'meaningful': 3, 'unit': 3, 'sentence': 3, 'as': 3, 'a': 3, 'words.': 2, 'word': 2, 'tokenizer': 2, 'splits': 2, ...})

# %% [markdown]
# ## word cloud
#
# Wordcloud is the pictorial representation of the word frequency of the dataset.WordCloud is easier to understand and gives a better idea about our textual data.

# %%
from wordcloud import WordCloud
from wordcloud import STOPWORDS  
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
words = []
for message in paragraph.split('.'):
    words.extend([word for word in message.split() if word not in STOPWORDS])
        
wordcloud = WordCloud(width = 1000, height = 500).generate(" ".join(words))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
